# %% [markdown]
# # L2 Clause Pipeline — Executable Reference
#
# This notebook wires the deterministic L2 pieces together: candidate extraction, normalization, and validation.
# Adapter (LLM) is optional and must be opt-in.

# %%
# Setup: ensure repo root on sys.path for imports
import os, sys, json
# notebook is at level2/ — go one level up to project root
repo_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from level2 import clause_extractor, normalizer, validator
from level2 import adapter as llm_adapter

INTENTS = [
    'investigate',
    'execute',
    'summarize',
    'ops',
]

CLAUSE_FIELDS = ['entity','operation','metric','time_window','environment','condition','constraint','output_format']
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       6     sys.path.insert(0, repo_root)
#       8 from level2 import clause_extractor, normalizer, validator
# ----> 9 from level2.llm_adapter import adapter as llm_adapter
#      11 INTENTS = [
#      12     'investigate',
#      13     'execute',
#      14     'summarize',
#      15     'ops',
#      16 ]
#      18 CLAUSE_FIELDS = ['entity','operation','metric','time_window','environment','condition','constraint','output_format']
#
# ModuleNotFoundError: No module named 'level2.llm_adapter'

# %%
def l2_pipeline(utterance: str, intent: str, use_adapter: bool = False) -> dict:
    """Run the L2 deterministic pipeline over an utterance.

    Returns the L2 output schema (dict).
    """
    if intent not in INTENTS:
        raise ValueError(f'unknown intent: {intent}')

    adapter_result = {}
    if use_adapter:
        adapter_result = llm_adapter.extract_clauses(utterance) or {}

    clauses, detectors, adapter_meta = clause_extractor.extract_candidates(utterance, adapter_result)
    normalized = normalizer.normalize_clauses(clauses)
    decision_state, details, ambiguity, feedback = validator.validate(normalized, intent)

    decision_trace = {
        'detectors_fired': detectors,
        'hard_rules_failed': details.get('hard_rules_failed', []),
        'soft_rules_passed': details.get('soft_rules_passed', []),
        'alternatives_eliminated': {},
    }

    out = {
        'utterance': utterance,
        'intent': intent,
        'clauses': normalized,
        'first_pass': 'success' if decision_state == 'accepted' else ('partial' if decision_state == 'needs_clarification' else 'failure'),
        'ambiguity_report': ambiguity,
        'decision_state': decision_state,
        'decision_trace': decision_trace,
        'feedback': feedback,
        'metadata': {
            'timestamp': __import__('datetime').datetime.utcnow().isoformat() + 'Z',
            'adapter_used': bool(use_adapter),
            'adapter_confidence': adapter_meta.get('confidence') if use_adapter else None,
        },
    }
    return out

# %%
# Example runs
samples = [
    ("Restart web-01 in prod immediately", 'execute'),
    ("Show CPU and memory for web-01 for the last 5m", 'investigate'),
    ("Delete db-02 in prod", 'execute'),
]

for utt, intent in samples:
    result = l2_pipeline(utt, intent, use_adapter=False)
    print('---')
    print(utt)
    print(json.dumps(result, indent=2))
# Out:
# ---
# Restart web-01 in prod immediately
# {
#   "utterance": "Restart web-01 in prod immediately",
#   "intent": "execute",
#   "clauses": {
#     "entity": [
#       "web-01"
#     ],
#     "operation": [
#       "restart",
#       "start"
#     ],
#     "metric": [],
#     "time_window": [],
#     "environment": [
#       "prod"
#     ],
#     "condition": [],
#     "constraint": [],
#     "output_format": []
#   },
#   "first_pass": "partial",
#   "ambiguity_report": {
#     "missing_clauses": [],
#     "conflicting_candidates": {
#       "operation": [
#         "restart",
#         "start"
#       ]
#     },
#     "policy_conflicts": [],
#     "needs_iteration": true
#   },
#   "decision_state": "needs_clarification",
#   "decision_trace": {
#     "detectors_fired": [
#       "adapter",
#       "regex_entity",
#       "keyword_operation",
#       "keyword_environment"
#     ],
#     "hard_rules_failed": [],
#     "soft_rules_passed": [],
#     "alternatives_eliminated": {}
#   },
#   "feedback": {
#     "focus_clause": "operation",
#     "reason": "conflicting_candidates",
#     "hints": [
#       "restart"
#     ]
#   },
#   "metadata": {
#     "timestamp": "2026-03-03T00:58:41.307405Z",
#     "adapter_used": false,
#     "adapter_confidence": null
#   }
# }
# ---
# Show CPU and memory for web-01 for the last 5m
# {
#   "utterance": "Show CPU and memory for web-01 for the last 5m",
#   "intent": "investigate",
#   "clauses": {
#     "entity": [
#       "web-01"
#     ],
#     "operation": [],
#     "metric": [
#       "cpu",
#       "memory"
#     ],
#     "time_window": [
#       "PT5M"
#     ],
#     "environment": [],
#     "condition": [],
#     "constraint": [],
#     "output_format": []
#   },
#   "first_pass": "success",
#   "ambiguity_report": {
#     "missing_clauses": [],
#     "conflicting_candidates": {},
#     "policy_conflicts": [],
#     "needs_iteration": false
#   },
#   "decision_state": "accepted",
#   "decision_trace": {
#     "detectors_fired": [
#       "adapter",
#       "regex_entity",
#       "regex_time_window",
#       "keyword_metric"
#     ],
#     "hard_rules_failed": [],
#     "soft_rules_passed": [
#       "has_time_window"
#     ],
#     "alternatives_eliminated": {}
#   },
#   "feedback": {
#     "focus_clause": null,
#     "reason": null,
#     "hints": []
#   },
#   "metadata": {
#     "timestamp": "2026-03-03T00:58:41.307787Z",
#     "adapter_used": false,
#     "adapter_confidence": null
#   }
# }
# ---
# Delete db-02 in prod
# {
#   "utterance": "Delete db-02 in prod",
#   "intent": "execute",
#   "clauses": {
#     "entity": [
#       "db-02"
#     ],
#     "operation": [
#       "delete"
#     ],
#     "metric": [],
#     "time_window": [],
#     "environment": [
#       "prod"
#     ],
#     "condition": [],
#     "constraint": [],
#     "output_format": []
#   },
#   "first_pass": "failure",
#   "ambiguity_report": {
#     "missing_clauses": [],
#     "conflicting_candidates": {},
#     "policy_conflicts": [
#       "delete_in_prod_requires_approval"
#     ],
#     "needs_iteration": false
#   },
#   "decision_state": "blocked",
#   "decision_trace": {
#     "detectors_fired": [
#       "adapter",
#       "regex_entity",
#       "keyword_operation",
#       "keyword_environment"
#     ],
#     "hard_rules_failed": [
#       "forbidden_delete_in_prod_without_approval"
#     ],
#     "soft_rules_passed": [],
#     "alternatives_eliminated": {}
#   },
#   "feedback": {
#     "focus_clause": "constraint",
#     "reason": "policy_requires_constraint",
#     "hints": [
#       "requires_approval"
#     ]
#   },
#   "metadata": {
#     "timestamp": "2026-03-03T00:58:41.307975Z",
#     "adapter_used": false,
#     "adapter_confidence": null
#   }
# }
# C:\Users\Ashokekumar\AppData\Local\Temp\ipykernel_14848\3852605441.py:34: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'timestamp': __import__('datetime').datetime.utcnow().isoformat() + 'Z',

# %% [markdown]
# ### Notes:
# - This notebook is an executable reference. In production, the adapter should be implemented under `level2/adapter.py` and adapter outputs must be re-validated by the deterministic validators.
# - The functions here are intentionally conservative; they expose ambiguity rather than guessing.
